# %% [markdown]
# ### Setup

# %% [raw]
# # Command Prompt Code
# 1. Install JDK 17
# 2. Install Python
# 3. On cmd, follow:
# '''
# python -m venv pyspark_env
# pyspark_env\Scripts\activate
#
# pip install pyspark notebook ipykernel
# python -m ipykernel install --user --name=pyspark_env --display-name "PySpark Env"
#
# jupyter notebook
# '''

# %%
# !pip install pyspark

# %%
import pandas as pd

# %%
type(pd.read_csv('Book1.csv'))
# Out:
# pandas.DataFrame

# %% [markdown]
# ### Start a Spark Session

# %%
import pyspark
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('Practice').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://shera:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.1.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Practice</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ### Creating Spark DataFrame

# %%
df_pyspark = spark.read.csv('Book1.csv')

# %%
df_pyspark
# Out:
# DataFrame[_c0: string, _c1: string]

# %%
df_pyspark.show()
# Out:
# +-------+---+
# |    _c0|_c1|
# +-------+---+
# |   Name|Age|
# |  Manan| 25|
# |Shubham| 24|
# |Shaswat| 30|
# +-------+---+

# %%
# To include headers in a csv file
df_pyspark = spark.read.option('header', 'true').csv('Book1.csv')
df_pyspark.show()
# Out:
# +-------+---+
# |   Name|Age|
# +-------+---+
# |  Manan| 25|
# |Shubham| 24|
# |Shaswat| 30|
# +-------+---+

# %%
type(df_pyspark)
# Out:
# pyspark.sql.classic.dataframe.DataFrame

# %%
# Get list of rows
df_pyspark.head(2)
# Out:
# [Row(Name='Manan', Age='25'), Row(Name='Shubham', Age='24')]

# %%
# Get info on columns
df_pyspark.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- Age: string (nullable = true)

# %% [markdown]
# ### Stop Spark Session

# %%
spark.stop()
